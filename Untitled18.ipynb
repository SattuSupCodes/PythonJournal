# %% [markdown]
# <a href="https://colab.research.google.com/github/SattuSupCodes/PythonJournal/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
def sigmoid(z):
  return 1.0/(1.0 + np.exp(-z))

# %%
def calculate_gradient(theta,x,y):
  m = y.size #no of instances
  return (x.T @ (sigmoid(x @ theta))) / m

# %%
def gradient_descent(x,y,alpha = 0.1, num_iter = 100, tol=1e-7):
  x_b = np.c_[np.ones(x.shape[0],1)]
